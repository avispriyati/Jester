# %%
pip install surprise
# Out:
# ...
#      |████████████████████████████████| 11.8 MB 5.4 MB/s
# ...
#   Created wheel for scikit-surprise: filename=scikit_surprise-1.1.1-cp37-cp37m-linux_x86_64.whl size=1630175 sha256=69967c78436a63f7e2c9f89bcf7e035ba6bd469858bfbe6c85e82444ca77d8b3
#   Stored in directory: /root/.cache/pip/wheels/76/44/74/b498c42be47b2406bd27994e16c5188e337c657025ab400c1c
# Successfully built scikit-surprise
# ...

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
from surprise import Reader, Dataset, SVD
from surprise.accuracy import rmse, mae
from surprise.model_selection import cross_validate
from surprise import accuracy
from surprise.model_selection import train_test_split

# %%
#Unzip the file
# !unzip j.zip
# Out:
# Archive:  j.zip
#   inflating: jester_items.csv
#   inflating: jester_ratings.csv

# %%
items = pd.read_csv('/content/jester_items.csv')

# %%
items.head()
# Out:
#    jokeId                                           jokeText
# 0       1  A man visits the doctor. The doctor says "I ha...
# 1       2  This couple had an excellent relationship goin...
# 2       3  Q. What's 200 feet long and has 4 teeth? \n\nA...
# 3       4  Q. What's the difference between a man and a t...
# 4       5  Q.\tWhat's O. J. Simpson's Internet address? \...

# %%
reader = Reader()
ratings = pd.read_csv('/content/jester_ratings.csv')
ratings.head()
# Out:
#    userId  jokeId  rating
# 0       1       5   0.219
# 1       1       7  -9.281
# 2       1       8  -9.281
# 3       1      13  -6.781
# 4       1      15   0.875

# %%
# trainset

reader = Reader()
data = Dataset.load_from_df(ratings[['userId','jokeId','rating']],reader)
trainset, testset = train_test_split(data, train_size=0.8, test_size=0.2)

type(data)
# Out:
# surprise.dataset.DatasetAutoFolds

# %%
model= SVD(n_epochs=10)
model.fit(trainset)
test_pred = model.test(testset)
print("Hasil SVD")
accuracy.rmse(test_pred, verbose=True)
# Out:
# Hasil SVD
# RMSE: 4.7625
# 4.76254316928844

# %%
# Run 5-fold cross-validation and then print results
cross_validate(model, data, measures=['RMSE'], cv=5, verbose=True)
# Out:
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    4.7698  4.7818  4.7795  4.7844  4.7850  4.7801  0.0055
# Fit time          82.46   82.46   83.25   82.01   82.30   82.50   0.41
# Test time         6.06    5.75    5.81    5.93    5.75    5.86    0.12
# {'fit_time': (82.45542359352112,
#   82.46119141578674,
#   83.24870586395264,
#   82.01282835006714,
#   82.2983238697052),
#  'test_rmse': array([4.76975462, 4.78179507, 4.77951743, 4.78438867, 4.78500644]),
#  'test_time': (6.058672666549683,
#   5.749335289001465,
#   5.807352781295776,
#   5.927875995635986,
#   5.753090143203735)}
